# %%
import pandas as pd
from torch.utils.data import Dataset
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
import random
import numpy
import math
import os
import re
import torch.optim as optim
import time
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using GPU:", torch.cuda.get_device_name(0))
else:
    device = torch.device("cpu")
    print("Using CPU")
# Out:
# Using GPU: NVIDIA A16

# %%
# dataset class

class MyDataset(Dataset):

    def __init__(self, csv_file):
        self.data_df = pd.read_csv(csv_file, header=None, sep='\t')
#         self.min_value = self.data_df.min().min()
#         self.max_value = self.data_df.max().max()
        
        self.min_value = self.data_df.min()
        self.max_value = self.data_df.max()

    def __len__(self):
        return len(self.data_df)

    def __getitem__(self, index):
#         image_values = torch.FloatTensor(self.data_df.iloc[index, 0:].values)
#         image_values = (image_values - self.min_value) / (self.max_value - self.min_value)
        
        image_values = torch.FloatTensor(self.data_df.iloc[index, 0:].values)

        # 计算最大值和最小值的差
        range_values = self.max_value - self.min_value
        # 处理全零列：如果最大值和最小值相等（即该列全为同一个值），则将范围设置为1以避免除以零
        range_values[range_values == 0] = 1

        # 进行归一化
        normalized_values = (image_values - self.min_value) / range_values
        
        return image_values.to(device)
    
    def plot_image(self, index):
        img = self.data_df.iloc[index, 0:].values.reshape(25, 233)
        # plt.title("label = " + str(self.data_df.iloc[index,0]))
        plt.title("label = " + self.filename)
        plt.imshow(img, interpolation='none', cmap='Blues')
        pass
    
    def unnormalize(self, tensor):
        return tensor * (self.max_value - self.min_value) + self.min_value
    
    pass

# functions to generate random data

def generate_random_image(size):
    random_data = torch.rand(size).to(device)
    return random_data


def generate_random_seed(size):
    random_data = torch.randn(size).to(device)
    return random_data


# discriminator class

class Discriminator(nn.Module):

    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(5825, 1200),
            nn.LeakyReLU(0.02),
            nn.LayerNorm(1200),
            nn.Linear(1200, 1),
            nn.Sigmoid()
        ).to(device)
        self.loss_function = nn.BCELoss()
        self.optimiser = optim.Adam(self.parameters(), lr=0.0001)

        # counter and accumulator for progress
        self.counter = 0;
        self.progress = []

        pass

    def forward(self, inputs):
        # simply run model
        return self.model(inputs)

    def train(self, inputs, targets):
        # calculate the output of the network
        outputs = self.forward(inputs)

        # calculate loss
        loss = self.loss_function(outputs, targets)

        # increase counter and accumulate error every 10
        self.counter += 1;
        if (self.counter % 10 == 0):
            self.progress.append(loss.item())
            pass
        if (self.counter % 10000 == 0):
            print("counter = ", self.counter)
            pass

        # zero gradients, perform a backward pass, update weights
        self.optimiser.zero_grad()
        loss.backward()
        self.optimiser.step()

        pass

    def plot_progress(self):
        df = pd.DataFrame(self.progress, columns=['loss'])
        df.plot(ylim=(0), figsize=(16, 8), alpha=0.1, marker='.', grid=True, yticks=(0, 0.25, 0.5))
        pass

    pass


# generator class

class Generator(nn.Module):

    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(100, 600),
            nn.LeakyReLU(0.02),
            nn.LayerNorm(600),
            nn.Linear(600, 5825),
            nn.Sigmoid()
        ).to(device)
        self.optimiser = optim.Adam(self.parameters(), lr=0.0001)
        # counter and accumulator for progress
        self.counter = 0;
        self.progress = []

    def forward(self, inputs):
        # simply run model
        return self.model(inputs)

    def train(self, D, inputs, targets):
        # calculate the output of the network
        g_output = self.forward(inputs)

        # pass onto Discriminator
        d_output = D.forward(g_output)

        # calculate error
        loss = D.loss_function(d_output, targets)

        # increase counter and accumulate error every 10
        self.counter += 1;
        if (self.counter % 10 == 0):
            self.progress.append(loss.item())
            pass

        # zero gradients, perform a backward pass, update weights
        self.optimiser.zero_grad()
        loss.backward()
        self.optimiser.step()

        pass

    def plot_progress(self):
        df = pd.DataFrame(self.progress, columns=['loss'])
        df.plot(ylim=(0), figsize=(16, 8), alpha=0.1, marker='.', grid=True, yticks=(0, 0.25, 0.5, 1.0))
        pass

    pass

# 定义一个从文件名中提取数字的函数
def extract_number(filename):
    match = re.search(r'\d+', filename)
    return int(match.group()) if match else 0

# %%
class MyDataset2(Dataset):#noisy_user

    def __init__(self, csv_file):
        self.data_df = pd.read_csv(csv_file, header=None, sep='\t')
#         self.min_value = self.data_df.min().min()
#         self.max_value = self.data_df.max().max()
        
        self.min_value = self.data_df.min()
        self.max_value = self.data_df.max()

    def __len__(self):
        return len(self.data_df)

    def __getitem__(self, index):
#         image_values = torch.FloatTensor(self.data_df.iloc[index, 0:].values)
#         image_values = (image_values - self.min_value) / (self.max_value - self.min_value)
        
        image_values = torch.FloatTensor(self.data_df.iloc[index, 0:].values)

        # 计算最大值和最小值的差
        range_values = self.max_value - self.min_value
        # 处理全零列：如果最大值和最小值相等（即该列全为同一个值），则将范围设置为1以避免除以零
        range_values[range_values == 0] = 1

        # 进行归一化
        normalized_values = (image_values - self.min_value) / range_values
        image_tensor = torch.tensor(normalized_values.values, dtype=torch.float)
        
        return image_tensor.to(device)
    
    def unnormalize(self, tensor):
        return tensor * (self.max_value - self.min_value) + self.min_value

# %%
def add_laplace_noise(data, scale):
    """为数据添加拉普拉斯噪声"""
    noise = numpy.random.laplace(0, scale, data.shape)
    noisy_data = data + noise * (data != 0)*0.01
    noisy_data[noisy_data < 0] = 0
    return noisy_data

# %%
user_noisy = []
total_output = []
rmse=0
filepath = './train_matrix.txt'
print(f"已加载文件: {filepath}")
dataset = MyDataset(filepath)

for k in range(339):
    image_data_tensor = dataset[k] #原始数据

    #start_time = time.time()  # 获取开始时间
    for i in range(300):# !!!!!!!!!!!!!!!!!!!!!!记得改回300
        if i == 0:
            # 第一轮使用原始数据
            real_data_tensor = image_data_tensor.cpu().numpy()
            user_noisy.append(real_data_tensor)
            real_data_tensor = torch.tensor(real_data_tensor, dtype=torch.float32, device=device)

        else:
            # 从第二轮开始添加噪声
            image_data_numpy = image_data_tensor.cpu().numpy()  # 转换为NumPy数组
            noisy_image_data_numpy = add_laplace_noise(image_data_numpy, 0.1)
            #计算加了噪声后的数据与原来数据的差异
            mse = numpy.mean((noisy_image_data_numpy - image_data_numpy) ** 2)
            #unnormalize_noisy_image_data_numpy = dataset.unnormalize(noisy_image_data_numpy)
           #print("第",i,"轮  ","MSE:", mse)
            user_noisy.append(noisy_image_data_numpy)
            # 将带有噪声的NumPy数组转换回PyTorch张量
            real_data_tensor = torch.tensor(noisy_image_data_numpy, dtype=torch.float32,device=device)

    user_noisy = numpy.array(user_noisy) 
    user_noisy.reshape(-1, 5825)
    numpy.savetxt('user_noisy.txt', user_noisy, delimiter='\t', fmt='%f')
    print("已保存文件user_noisy.txt")
    
    filepath = './user_noisy.txt'
    print(f"已加载文件: {filepath}")
    dataset2 = MyDataset2(filepath)

    D = Discriminator()

    #for k in range(339):
    #image_data_tensor = dataset2[0] #原始数据，

    start_time = time.time()  # 获取开始时间
    for i in range(300):# !!!!!!!!!!!!!!!!!!!!!!记得改回300
        image_data_tensor = dataset2[i]
        #训练判别器 - 真实数据
        D.train(real_data_tensor, torch.cuda.FloatTensor([1.0], device=device))

        #训练判别器 - 生成的假数据
        fake_data = generate_random_image(5825).to(device)
        D.train(fake_data, torch.cuda.FloatTensor([0.0], device=device))
        pass

    # create Discriminator and Generator
    # D = Discriminator().to(device)
    G = Generator().to(device)

    epochs = 4
    print("start, 开始第 {} 个用户的训练".format(k+1))
    #print("start, 开始第1个用户的训练")

    for epoch in range(epochs):
        print("epoch = ", epoch + 1)

        # train Discriminator and Generator

        for image_data_tensor in dataset2:
    #         image_data_tensor = torch.from_numpy(image_data_tensor).float()
    #         image_data_tensor = image_data_tensor.to(device)

            true_labels = torch.tensor([1.0], dtype=torch.float).to(device)
            D.train(image_data_tensor, true_labels)

            fake_images = G.forward(generate_random_seed(100)).detach()
            false_labels = torch.tensor([0.0], dtype=torch.float).to(device)
            D.train(fake_images, false_labels)

            # train generator
            for i in range(5):
                G.train(D, generate_random_seed(100), torch.tensor([1.0], dtype=torch.float).to(device))
            pass
    pass
    print("finish, 结束第 {} 个用户的训练".format(k+1))
    #print("finish, 结束第1个用户的训练")

    output = G.forward(generate_random_seed(100))
    output_cpu = output.detach().cpu().numpy()
    unnormalize_output_cpu = dataset2.unnormalize(output_cpu)
    total_output.append(unnormalize_output_cpu)
    #numpy.savetxt('output.txt', output_cpu, delimiter='\t', fmt='%f')


    sum = 0
    # 获取第k个用户真实数据
    #image_values = dataset[k]  # 使用__getitem__方法
    image_values = dataset2.data_df.iloc[0, 0:].values
    for i in range(5825):
        # 获取第k个用户第i个服务数据，与生成器结果进行计算误差
        sum += (output_cpu[i] - image_values[i].item())**2

    sum /= 5825
    sum = math.sqrt(sum)
    rmse += sum
    print("当前用户误差：" + str(sum))
    end_time = time.time()  # 获取结束时间
    elapsed_time = end_time - start_time  # 计算经过的时间
    print(f"Elapsed time: {elapsed_time} seconds")
    user_noisy = []
# Out:
# 已加载文件: ./train_matrix.txt
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 1 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 1 个用户的训练
# 当前用户误差：1.1586695888993337
# Elapsed time: 63.763293743133545 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 2 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 2 个用户的训练
# 当前用户误差：0.4687090034198183
# Elapsed time: 63.78383755683899 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 3 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 3 个用户的训练
# 当前用户误差：0.7933945046468757
# Elapsed time: 63.71865439414978 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 4 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 4 个用户的训练
# 当前用户误差：0.47935380619495577
# Elapsed time: 63.567615270614624 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 5 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 5 个用户的训练
# 当前用户误差：0.5856792997765888
# Elapsed time: 63.75559449195862 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 6 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 6 个用户的训练
# 当前用户误差：0.6026638318147542
# Elapsed time: 63.783324003219604 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 7 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 7 个用户的训练
# 当前用户误差：0.46810999883481186
# Elapsed time: 63.28496861457825 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 8 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 8 个用户的训练
# 当前用户误差：0.6131232638351651
# Elapsed time: 64.04017615318298 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 9 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 9 个用户的训练
# 当前用户误差：0.46849892177674957
# Elapsed time: 63.85222578048706 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 10 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 10 个用户的训练
# 当前用户误差：0.5095374274119313
# Elapsed time: 63.43739581108093 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 11 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 11 个用户的训练
# 当前用户误差：1.2592473203804293
# Elapsed time: 63.70178937911987 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 12 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 12 个用户的训练
# 当前用户误差：0.4247452002251278
# Elapsed time: 63.71119928359985 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 13 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 13 个用户的训练
# 当前用户误差：0.48978694341142254
# Elapsed time: 63.87667536735535 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 14 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 14 个用户的训练
# 当前用户误差：0.5242170085223133
# Elapsed time: 63.78751564025879 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 15 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 15 个用户的训练
# 当前用户误差：0.5807913023802069
# Elapsed time: 63.40836501121521 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 16 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 16 个用户的训练
# 当前用户误差：0.42953841459655323
# Elapsed time: 63.958131074905396 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 17 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 17 个用户的训练
# 当前用户误差：0.553938151544632
# Elapsed time: 63.64375352859497 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 18 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 18 个用户的训练
# 当前用户误差：0.5521375264703644
# Elapsed time: 63.91261649131775 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 19 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 19 个用户的训练
# 当前用户误差：0.6037377531063568
# Elapsed time: 64.0894410610199 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 20 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 20 个用户的训练
# 当前用户误差：0.5893188657295204
# Elapsed time: 64.17867112159729 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 21 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 21 个用户的训练
# 当前用户误差：0.4317132946932387
# Elapsed time: 64.68253064155579 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 22 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 22 个用户的训练
# 当前用户误差：0.4742842955761181
# Elapsed time: 64.2219557762146 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 23 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 23 个用户的训练
# 当前用户误差：0.39592192714800895
# Elapsed time: 64.49843525886536 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 24 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 24 个用户的训练
# 当前用户误差：0.5318363844359636
# Elapsed time: 64.4813642501831 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 25 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 25 个用户的训练
# 当前用户误差：0.5893977196100939
# Elapsed time: 64.2999472618103 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 26 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 26 个用户的训练
# 当前用户误差：0.3557783234738789
# Elapsed time: 64.48123216629028 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 27 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 27 个用户的训练
# 当前用户误差：0.4698929000505547
# Elapsed time: 64.72062754631042 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 28 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 28 个用户的训练
# 当前用户误差：0.42100581078852023
# Elapsed time: 65.15937542915344 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 29 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 29 个用户的训练
# 当前用户误差：0.46589278258991723
# Elapsed time: 65.28795647621155 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 30 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 30 个用户的训练
# 当前用户误差：0.5654275928328139
# Elapsed time: 64.46870946884155 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 31 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 31 个用户的训练
# 当前用户误差：0.612528221861374
# Elapsed time: 64.4334716796875 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 32 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 32 个用户的训练
# 当前用户误差：0.5522854725815703
# Elapsed time: 64.1938898563385 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 33 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 33 个用户的训练
# 当前用户误差：1.343011367718141
# Elapsed time: 63.96121692657471 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 34 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 34 个用户的训练
# 当前用户误差：0.5082556491192658
# Elapsed time: 64.12910485267639 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 35 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 35 个用户的训练
# 当前用户误差：0.31626018958648416
# Elapsed time: 64.25066375732422 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 36 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 36 个用户的训练
# 当前用户误差：0.49103746017695343
# Elapsed time: 64.22716045379639 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 37 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 37 个用户的训练
# 当前用户误差：0.4762533524557068
# Elapsed time: 64.09963464736938 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 38 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 38 个用户的训练
# 当前用户误差：0.5873751338545982
# Elapsed time: 63.996039628982544 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 39 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 39 个用户的训练
# 当前用户误差：0.5740359176657779
# Elapsed time: 64.4219720363617 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 40 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 40 个用户的训练
# 当前用户误差：0.6448914785327208
# Elapsed time: 64.49669671058655 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 41 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 41 个用户的训练
# 当前用户误差：0.581585790817237
# Elapsed time: 64.68558025360107 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 42 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 42 个用户的训练
# 当前用户误差：0.37754545980165893
# Elapsed time: 64.10410523414612 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 43 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 43 个用户的训练
# 当前用户误差：0.41232653420087256
# Elapsed time: 64.66183757781982 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 44 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 44 个用户的训练
# 当前用户误差：0.4187822944525346
# Elapsed time: 64.94510293006897 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 45 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 45 个用户的训练
# 当前用户误差：0.44137341642631467
# Elapsed time: 64.96005010604858 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 46 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 46 个用户的训练
# 当前用户误差：0.5432942550453105
# Elapsed time: 64.75779843330383 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 47 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 47 个用户的训练
# 当前用户误差：0.4157686622497268
# Elapsed time: 65.11323881149292 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 48 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 48 个用户的训练
# 当前用户误差：0.5860746239008416
# Elapsed time: 65.05396485328674 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 49 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 49 个用户的训练
# 当前用户误差：0.6569301674867359
# Elapsed time: 64.68118381500244 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 50 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 50 个用户的训练
# 当前用户误差：0.4968452305377208
# Elapsed time: 64.49659371376038 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 51 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 51 个用户的训练
# 当前用户误差：0.41289038233284225
# Elapsed time: 64.81447958946228 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 52 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 52 个用户的训练
# 当前用户误差：0.5857026997524132
# Elapsed time: 64.82256388664246 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 53 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 53 个用户的训练
# 当前用户误差：0.4153859893008761
# Elapsed time: 63.99856686592102 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 54 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 54 个用户的训练
# 当前用户误差：0.4025500129767664
# Elapsed time: 64.3925154209137 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 55 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 55 个用户的训练
# 当前用户误差：0.49013463203450847
# Elapsed time: 63.926581382751465 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 56 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 56 个用户的训练
# 当前用户误差：0.38653278344016667
# Elapsed time: 64.92288398742676 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 57 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 57 个用户的训练
# 当前用户误差：0.4287347144849352
# Elapsed time: 64.10787296295166 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 58 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 58 个用户的训练
# 当前用户误差：0.48313819893815435
# Elapsed time: 64.55446338653564 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 59 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 59 个用户的训练
# 当前用户误差：0.4703416974237551
# Elapsed time: 64.68537759780884 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 60 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 60 个用户的训练
# 当前用户误差：0.4197901292855303
# Elapsed time: 64.55480241775513 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 61 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 61 个用户的训练
# 当前用户误差：0.8799588475446225
# Elapsed time: 64.4536817073822 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 62 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 62 个用户的训练
# 当前用户误差：0.4143204433075272
# Elapsed time: 65.08396077156067 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 63 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 63 个用户的训练
# 当前用户误差：0.5649753628391114
# Elapsed time: 64.81161165237427 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 64 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 64 个用户的训练
# 当前用户误差：0.6498591920526671
# Elapsed time: 64.99072170257568 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 65 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 65 个用户的训练
# 当前用户误差：0.465445916502868
# Elapsed time: 64.64681077003479 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 66 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 66 个用户的训练
# 当前用户误差：0.43714776871841227
# Elapsed time: 65.59124231338501 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 67 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 67 个用户的训练
# 当前用户误差：0.5134541327170675
# Elapsed time: 64.35805654525757 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 68 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 68 个用户的训练
# 当前用户误差：0.5074312150336986
# Elapsed time: 64.78669309616089 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 69 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 69 个用户的训练
# 当前用户误差：0.5358860332031652
# Elapsed time: 64.66826009750366 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 70 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 70 个用户的训练
# 当前用户误差：0.4236126534102109
# Elapsed time: 64.07535529136658 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 71 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 71 个用户的训练
# 当前用户误差：0.46367102096075985
# Elapsed time: 64.52748680114746 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 72 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 72 个用户的训练
# 当前用户误差：0.4980551722375577
# Elapsed time: 64.46561646461487 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 73 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 73 个用户的训练
# 当前用户误差：0.3998240074828988
# Elapsed time: 64.13328385353088 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 74 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 74 个用户的训练
# 当前用户误差：0.4061040317200215
# Elapsed time: 64.3293604850769 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 75 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 75 个用户的训练
# 当前用户误差：0.3884466672608961
# Elapsed time: 64.1987714767456 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 76 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 76 个用户的训练
# 当前用户误差：0.43161662098287296
# Elapsed time: 64.32243347167969 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 77 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 77 个用户的训练
# 当前用户误差：0.5381788620760637
# Elapsed time: 64.25835943222046 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 78 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 78 个用户的训练
# 当前用户误差：0.5026704902291858
# Elapsed time: 64.01838660240173 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 79 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 79 个用户的训练
# 当前用户误差：0.5847111068957542
# Elapsed time: 64.02015805244446 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 80 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 80 个用户的训练
# 当前用户误差：0.5288086240292692
# Elapsed time: 64.50991678237915 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 81 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 81 个用户的训练
# 当前用户误差：0.559320790198614
# Elapsed time: 64.01302981376648 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 82 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 82 个用户的训练
# 当前用户误差：1.217470574292356
# Elapsed time: 64.2800555229187 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 83 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 83 个用户的训练
# 当前用户误差：1.2548827519407904
# Elapsed time: 65.8395881652832 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 84 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 84 个用户的训练
# 当前用户误差：0.4557034608692896
# Elapsed time: 67.16272974014282 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 85 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 85 个用户的训练
# 当前用户误差：0.4970096034812287
# Elapsed time: 67.0601658821106 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 86 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 86 个用户的训练
# 当前用户误差：0.4948366722540677
# Elapsed time: 66.77644157409668 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 87 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 87 个用户的训练
# 当前用户误差：0.4092923106363342
# Elapsed time: 66.14637446403503 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 88 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 88 个用户的训练
# 当前用户误差：0.347103260140868
# Elapsed time: 66.48649621009827 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 89 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 89 个用户的训练
# 当前用户误差：0.4597513651816585
# Elapsed time: 67.39251780509949 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 90 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 90 个用户的训练
# 当前用户误差：0.3443072885309737
# Elapsed time: 66.89320206642151 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 91 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 91 个用户的训练
# 当前用户误差：0.4258224587183706
# Elapsed time: 66.70311999320984 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 92 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 92 个用户的训练
# 当前用户误差：0.6370692740734653
# Elapsed time: 65.75576424598694 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 93 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 93 个用户的训练
# 当前用户误差：0.5179958402207179
# Elapsed time: 64.79055690765381 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 94 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 94 个用户的训练
# 当前用户误差：0.3495903719495571
# Elapsed time: 65.53489470481873 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 95 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 95 个用户的训练
# 当前用户误差：0.5119400531149831
# Elapsed time: 65.93278074264526 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 96 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 96 个用户的训练
# 当前用户误差：0.5913584140050515
# Elapsed time: 67.07309031486511 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 97 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 97 个用户的训练
# 当前用户误差：0.41306138449870866
# Elapsed time: 66.83672308921814 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 98 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 98 个用户的训练
# 当前用户误差：0.5188541141967746
# Elapsed time: 67.01841115951538 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 99 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 99 个用户的训练
# 当前用户误差：0.3939746873063958
# Elapsed time: 66.58224415779114 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 100 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 100 个用户的训练
# 当前用户误差：0.49497944159805685
# Elapsed time: 65.09998273849487 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 101 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 101 个用户的训练
# 当前用户误差：0.4339933898680772
# Elapsed time: 63.556514739990234 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 102 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 102 个用户的训练
# 当前用户误差：0.5097720359352816
# Elapsed time: 63.53312349319458 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 103 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 103 个用户的训练
# 当前用户误差：0.3705887643109669
# Elapsed time: 63.23473000526428 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 104 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 104 个用户的训练
# 当前用户误差：0.543024302579282
# Elapsed time: 63.4659206867218 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 105 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 105 个用户的训练
# 当前用户误差：0.41857778846739224
# Elapsed time: 63.00923562049866 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 106 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 106 个用户的训练
# 当前用户误差：0.5460003458326773
# Elapsed time: 62.920968770980835 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 107 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 107 个用户的训练
# 当前用户误差：0.42605365508780974
# Elapsed time: 63.33671307563782 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 108 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 108 个用户的训练
# 当前用户误差：0.39040891053620885
# Elapsed time: 63.13225984573364 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 109 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 109 个用户的训练
# 当前用户误差：0.45903882790818845
# Elapsed time: 63.07610321044922 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 110 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 110 个用户的训练
# 当前用户误差：0.5234746893870771
# Elapsed time: 63.31455373764038 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 111 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 111 个用户的训练
# 当前用户误差：0.7025587593360728
# Elapsed time: 63.149190187454224 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 112 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 112 个用户的训练
# 当前用户误差：0.7150354147153799
# Elapsed time: 62.8659348487854 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 113 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 113 个用户的训练
# 当前用户误差：0.7171730835294903
# Elapsed time: 63.45008063316345 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 114 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 114 个用户的训练
# 当前用户误差：0.4618633604131154
# Elapsed time: 62.29674744606018 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 115 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 115 个用户的训练
# 当前用户误差：0.7311329135747805
# Elapsed time: 62.470678091049194 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 116 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 116 个用户的训练
# 当前用户误差：0.7020680421229548
# Elapsed time: 62.423866510391235 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 117 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 117 个用户的训练
# 当前用户误差：0.4799715020191463
# Elapsed time: 62.06729984283447 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 118 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 118 个用户的训练
# 当前用户误差：0.5536249716084616
# Elapsed time: 62.44087338447571 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 119 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 119 个用户的训练
# 当前用户误差：0.4613227499463676
# Elapsed time: 62.14830231666565 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 120 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 120 个用户的训练
# 当前用户误差：0.4311837327029491
# Elapsed time: 62.246098279953 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 121 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 121 个用户的训练
# 当前用户误差：0.4536341001866493
# Elapsed time: 62.629743814468384 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 122 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 122 个用户的训练
# 当前用户误差：0.319121322665786
# Elapsed time: 62.15425181388855 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 123 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 123 个用户的训练
# 当前用户误差：1.3637719308621206
# Elapsed time: 62.43624424934387 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 124 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 124 个用户的训练
# 当前用户误差：1.4198544501212584
# Elapsed time: 62.289631843566895 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 125 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 125 个用户的训练
# 当前用户误差：1.3322928176112363
# Elapsed time: 62.7147057056427 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 126 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 126 个用户的训练
# 当前用户误差：0.8177318625547054
# Elapsed time: 62.516178131103516 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 127 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 127 个用户的训练
# 当前用户误差：0.6689953875808895
# Elapsed time: 62.21929860115051 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 128 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 128 个用户的训练
# 当前用户误差：0.6903104476849153
# Elapsed time: 62.25024104118347 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 129 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 129 个用户的训练
# 当前用户误差：0.6584881005798506
# Elapsed time: 61.984898805618286 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 130 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 130 个用户的训练
# 当前用户误差：0.6742357408058535
# Elapsed time: 62.371691942214966 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 131 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 131 个用户的训练
# 当前用户误差：0.47531185467777604
# Elapsed time: 62.40833520889282 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 132 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 132 个用户的训练
# 当前用户误差：0.45242267197621755
# Elapsed time: 62.02490830421448 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 133 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 133 个用户的训练
# 当前用户误差：0.4938177576182624
# Elapsed time: 62.2366509437561 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 134 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 134 个用户的训练
# 当前用户误差：0.6272828988745989
# Elapsed time: 62.26662540435791 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 135 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 135 个用户的训练
# 当前用户误差：0.5015160615236754
# Elapsed time: 63.06423592567444 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 136 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 136 个用户的训练
# 当前用户误差：0.4808830906069188
# Elapsed time: 63.91724634170532 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 137 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 137 个用户的训练
# 当前用户误差：0.503667747488771
# Elapsed time: 63.775657415390015 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 138 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 138 个用户的训练
# 当前用户误差：0.6185530914490165
# Elapsed time: 63.85760569572449 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 139 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 139 个用户的训练
# 当前用户误差：0.6244698333961628
# Elapsed time: 63.479445695877075 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 140 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 140 个用户的训练
# 当前用户误差：0.4091193122336704
# Elapsed time: 63.133848667144775 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 141 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 141 个用户的训练
# 当前用户误差：0.8486612663698423
# Elapsed time: 63.38749051094055 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 142 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 142 个用户的训练
# 当前用户误差：0.8836009436148095
# Elapsed time: 63.361473083496094 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 143 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 143 个用户的训练
# 当前用户误差：1.1658530725453757
# Elapsed time: 63.309852600097656 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 144 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 144 个用户的训练
# 当前用户误差：1.198232451224969
# Elapsed time: 63.628857374191284 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 145 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 145 个用户的训练
# 当前用户误差：0.6133217705353803
# Elapsed time: 62.8665816783905 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 146 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 146 个用户的训练
# 当前用户误差：0.5101283162195099
# Elapsed time: 63.46947121620178 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 147 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 147 个用户的训练
# 当前用户误差：0.3446145682573533
# Elapsed time: 63.41267251968384 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 148 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 148 个用户的训练
# 当前用户误差：0.5667663696017277
# Elapsed time: 63.9194757938385 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 149 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 149 个用户的训练
# 当前用户误差：0.4227311153593839
# Elapsed time: 63.58845138549805 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 150 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 150 个用户的训练
# 当前用户误差：0.5078314282817109
# Elapsed time: 62.884806632995605 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 151 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 151 个用户的训练
# 当前用户误差：0.3838338393983518
# Elapsed time: 63.52641582489014 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 152 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 152 个用户的训练
# 当前用户误差：0.4381158490375023
# Elapsed time: 63.20307922363281 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 153 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 153 个用户的训练
# 当前用户误差：0.4653853576661425
# Elapsed time: 63.601946115493774 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 154 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 154 个用户的训练
# 当前用户误差：0.2994525432617205
# Elapsed time: 63.036667346954346 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 155 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 155 个用户的训练
# 当前用户误差：0.48284007492708375
# Elapsed time: 63.93257021903992 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 156 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 156 个用户的训练
# 当前用户误差：0.5067853764612574
# Elapsed time: 64.12225985527039 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 157 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 157 个用户的训练
# 当前用户误差：0.5897055887282927
# Elapsed time: 63.94402623176575 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 158 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 158 个用户的训练
# 当前用户误差：0.45949939627834246
# Elapsed time: 63.76861524581909 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 159 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 159 个用户的训练
# 当前用户误差：0.5772646561020509
# Elapsed time: 63.85722041130066 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 160 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 160 个用户的训练
# 当前用户误差：0.8183264326564258
# Elapsed time: 63.469900131225586 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 161 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 161 个用户的训练
# 当前用户误差：1.404684145347184
# Elapsed time: 63.56318426132202 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 162 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 162 个用户的训练
# 当前用户误差：0.629274334462131
# Elapsed time: 64.01304841041565 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 163 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 163 个用户的训练
# 当前用户误差：0.4518743446515281
# Elapsed time: 63.63135814666748 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 164 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 164 个用户的训练
# 当前用户误差：1.0121744870099494
# Elapsed time: 63.58672213554382 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 165 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 165 个用户的训练
# 当前用户误差：1.322763162511763
# Elapsed time: 63.278550148010254 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 166 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 166 个用户的训练
# 当前用户误差：0.44182509020379346
# Elapsed time: 63.04704141616821 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 167 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 167 个用户的训练
# 当前用户误差：0.512044652289474
# Elapsed time: 63.22147536277771 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 168 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 168 个用户的训练
# 当前用户误差：0.6103804381446171
# Elapsed time: 63.421019554138184 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 169 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 169 个用户的训练
# 当前用户误差：0.460462286504178
# Elapsed time: 62.912561655044556 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 170 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 170 个用户的训练
# 当前用户误差：0.5692174042808341
# Elapsed time: 63.297226428985596 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 171 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 171 个用户的训练
# 当前用户误差：0.5301251796469069
# Elapsed time: 63.08932638168335 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 172 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 172 个用户的训练
# 当前用户误差：0.5080262337167808
# Elapsed time: 63.47289562225342 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 173 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 173 个用户的训练
# 当前用户误差：0.4215925710313471
# Elapsed time: 63.390586853027344 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 174 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 174 个用户的训练
# 当前用户误差：0.5210287905318164
# Elapsed time: 63.37699818611145 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 175 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 175 个用户的训练
# 当前用户误差：0.37502944511923425
# Elapsed time: 63.23758411407471 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 176 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 176 个用户的训练
# 当前用户误差：0.3395246577626859
# Elapsed time: 63.650322914123535 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 177 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 177 个用户的训练
# 当前用户误差：0.4628927588613345
# Elapsed time: 63.51785135269165 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 178 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 178 个用户的训练
# 当前用户误差：0.608404648568063
# Elapsed time: 63.03264403343201 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 179 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 179 个用户的训练
# 当前用户误差：0.4858975857195329
# Elapsed time: 63.574918270111084 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 180 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 180 个用户的训练
# 当前用户误差：0.4918939090569493
# Elapsed time: 63.7812020778656 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 181 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 181 个用户的训练
# 当前用户误差：0.45552157271908156
# Elapsed time: 65.2939076423645 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 182 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 182 个用户的训练
# 当前用户误差：0.5153609142723559
# Elapsed time: 64.7932448387146 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 183 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 183 个用户的训练
# 当前用户误差：1.007978844908808
# Elapsed time: 65.58601498603821 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 184 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 184 个用户的训练
# 当前用户误差：0.9809703443445733
# Elapsed time: 64.55811858177185 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 185 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 185 个用户的训练
# 当前用户误差：0.45287924489893866
# Elapsed time: 64.554208278656 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 186 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 186 个用户的训练
# 当前用户误差：0.5712497908429556
# Elapsed time: 64.36345434188843 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 187 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 187 个用户的训练
# 当前用户误差：0.5025836265805997
# Elapsed time: 64.28006982803345 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 188 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 188 个用户的训练
# 当前用户误差：0.383974353671433
# Elapsed time: 64.38749599456787 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 189 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 189 个用户的训练
# 当前用户误差：0.5266907446571657
# Elapsed time: 64.33673119544983 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 190 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 190 个用户的训练
# 当前用户误差：0.41606122886639574
# Elapsed time: 63.569334506988525 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 191 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 191 个用户的训练
# 当前用户误差：0.4833854298340758
# Elapsed time: 63.370163917541504 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 192 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 192 个用户的训练
# 当前用户误差：0.45744823196194445
# Elapsed time: 63.621458292007446 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 193 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 193 个用户的训练
# 当前用户误差：0.5315809955637634
# Elapsed time: 63.39122247695923 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 194 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 194 个用户的训练
# 当前用户误差：0.421183135592716
# Elapsed time: 63.47244191169739 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 195 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 195 个用户的训练
# 当前用户误差：0.47604772483234414
# Elapsed time: 63.02985739707947 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 196 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 196 个用户的训练
# 当前用户误差：0.5138428481888817
# Elapsed time: 63.41643571853638 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 197 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 197 个用户的训练
# 当前用户误差：0.8563587338401976
# Elapsed time: 63.829493284225464 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 198 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 198 个用户的训练
# 当前用户误差：0.8766366320395182
# Elapsed time: 63.2713418006897 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 199 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 199 个用户的训练
# 当前用户误差：0.594563286294999
# Elapsed time: 63.204782485961914 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 200 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 200 个用户的训练
# 当前用户误差：0.42886092190012776
# Elapsed time: 63.35804343223572 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 201 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 201 个用户的训练
# 当前用户误差：0.6569563544052971
# Elapsed time: 63.34115147590637 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 202 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 202 个用户的训练
# 当前用户误差：0.7562117426831594
# Elapsed time: 63.18697905540466 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 203 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 203 个用户的训练
# 当前用户误差：0.608404316929771
# Elapsed time: 63.04432988166809 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 204 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 204 个用户的训练
# 当前用户误差：0.7713189829801961
# Elapsed time: 63.64017915725708 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 205 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 205 个用户的训练
# 当前用户误差：0.4548690094076673
# Elapsed time: 63.60886764526367 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 206 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 206 个用户的训练
# 当前用户误差：0.6159977224689983
# Elapsed time: 63.329123735427856 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 207 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 207 个用户的训练
# 当前用户误差：0.46813583826459293
# Elapsed time: 63.33554697036743 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 208 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 208 个用户的训练
# 当前用户误差：0.32428697296801573
# Elapsed time: 63.37323760986328 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 209 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 209 个用户的训练
# 当前用户误差：0.4147215973004126
# Elapsed time: 63.47117757797241 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 210 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 210 个用户的训练
# 当前用户误差：0.389159438363035
# Elapsed time: 63.0306134223938 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 211 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 211 个用户的训练
# 当前用户误差：0.5112809793275559
# Elapsed time: 63.60741090774536 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 212 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 212 个用户的训练
# 当前用户误差：0.49698674649194324
# Elapsed time: 63.52494430541992 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 213 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 213 个用户的训练
# 当前用户误差：0.5335546869324833
# Elapsed time: 63.562361001968384 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 214 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 214 个用户的训练
# 当前用户误差：0.4355119027501533
# Elapsed time: 64.13123869895935 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 215 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 215 个用户的训练
# 当前用户误差：0.38128165873433173
# Elapsed time: 64.20159435272217 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 216 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 216 个用户的训练
# 当前用户误差：0.560086196578285
# Elapsed time: 63.88979530334473 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 217 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 217 个用户的训练
# 当前用户误差：0.5415249729531263
# Elapsed time: 63.668604612350464 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 218 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 218 个用户的训练
# 当前用户误差：0.5443632467524608
# Elapsed time: 63.48042678833008 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 219 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 219 个用户的训练
# 当前用户误差：0.49806262032755505
# Elapsed time: 64.509197473526 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 220 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 220 个用户的训练
# 当前用户误差：0.39596195327947176
# Elapsed time: 64.99343967437744 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 221 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 221 个用户的训练
# 当前用户误差：0.4131014598787896
# Elapsed time: 63.27613306045532 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 222 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 222 个用户的训练
# 当前用户误差：1.245619103507506
# Elapsed time: 63.779338359832764 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 223 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 223 个用户的训练
# 当前用户误差：0.6172177770704997
# Elapsed time: 66.23976039886475 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 224 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 224 个用户的训练
# 当前用户误差：0.5274171033751642
# Elapsed time: 66.59084701538086 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 225 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 225 个用户的训练
# 当前用户误差：0.5329105032406437
# Elapsed time: 66.18695092201233 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 226 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 226 个用户的训练
# 当前用户误差：0.4393449486914265
# Elapsed time: 65.76759243011475 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 227 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 227 个用户的训练
# 当前用户误差：0.4987462471649292
# Elapsed time: 66.09698057174683 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 228 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 228 个用户的训练
# 当前用户误差：0.537662600640056
# Elapsed time: 65.12545275688171 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 229 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 229 个用户的训练
# 当前用户误差：0.3749988938072958
# Elapsed time: 63.857959032058716 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 230 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 230 个用户的训练
# 当前用户误差：0.45691729416782106
# Elapsed time: 63.853259325027466 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 231 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 231 个用户的训练
# 当前用户误差：0.48409712867138704
# Elapsed time: 63.6361083984375 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 232 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 232 个用户的训练
# 当前用户误差：0.34008476115964653
# Elapsed time: 63.543999433517456 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 233 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 233 个用户的训练
# 当前用户误差：0.738004473805775
# Elapsed time: 63.386226415634155 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 234 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 234 个用户的训练
# 当前用户误差：0.5492746926710325
# Elapsed time: 63.64602971076965 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 235 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 235 个用户的训练
# 当前用户误差：0.5018993811641197
# Elapsed time: 63.5979266166687 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 236 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 236 个用户的训练
# 当前用户误差：0.422979638071077
# Elapsed time: 63.41147208213806 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 237 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 237 个用户的训练
# 当前用户误差：0.4391194269741761
# Elapsed time: 64.66425228118896 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 238 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 238 个用户的训练
# 当前用户误差：0.5640336507711696
# Elapsed time: 65.60545182228088 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 239 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 239 个用户的训练
# 当前用户误差：0.5810558662810996
# Elapsed time: 63.42854022979736 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 240 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 240 个用户的训练
# 当前用户误差：0.5257639346773194
# Elapsed time: 66.17803812026978 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 241 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 241 个用户的训练
# 当前用户误差：0.596276627884847
# Elapsed time: 65.26723003387451 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 242 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 242 个用户的训练
# 当前用户误差：0.59104062789337
# Elapsed time: 63.48115134239197 seconds
# ...
# epoch =  3
# epoch =  4
# finish, 结束第 249 个用户的训练
# 当前用户误差：0.2853963773874925
# Elapsed time: 63.28394842147827 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 250 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 250 个用户的训练
# 当前用户误差：0.5859591617743712
# Elapsed time: 63.0439453125 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 251 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 251 个用户的训练
# 当前用户误差：0.30895129054808995
# Elapsed time: 62.835938453674316 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 252 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 252 个用户的训练
# 当前用户误差：0.4769067998403869
# Elapsed time: 63.347535133361816 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 253 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 253 个用户的训练
# 当前用户误差：0.4543522150940664
# Elapsed time: 63.06754922866821 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 254 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 254 个用户的训练
# 当前用户误差：0.3716168211868625
# Elapsed time: 62.84063529968262 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 255 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 255 个用户的训练
# 当前用户误差：0.5537347796817556
# Elapsed time: 63.056735038757324 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 256 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 256 个用户的训练
# 当前用户误差：0.6853103374492693
# Elapsed time: 62.983065605163574 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 257 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 257 个用户的训练
# 当前用户误差：0.36479426537669934
# Elapsed time: 63.24541091918945 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 258 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 258 个用户的训练
# 当前用户误差：0.3468205061719342
# Elapsed time: 62.96794509887695 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 259 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 259 个用户的训练
# 当前用户误差：0.4868382391275523
# Elapsed time: 62.895516872406006 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 260 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 260 个用户的训练
# 当前用户误差：0.45113046581218946
# Elapsed time: 63.260310649871826 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 261 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 261 个用户的训练
# 当前用户误差：0.4440944359963372
# Elapsed time: 63.10526204109192 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 262 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 262 个用户的训练
# 当前用户误差：0.507586273987262
# Elapsed time: 62.98087453842163 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 263 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 263 个用户的训练
# 当前用户误差：0.4631789391007623
# Elapsed time: 63.077065229415894 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 264 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 264 个用户的训练
# 当前用户误差：0.458771398795005
# Elapsed time: 63.102795362472534 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 265 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 265 个用户的训练
# 当前用户误差：0.9475716310340694
# Elapsed time: 63.218894958496094 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 266 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 266 个用户的训练
# 当前用户误差：0.5808363944513303
# Elapsed time: 62.60038113594055 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 267 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 267 个用户的训练
# 当前用户误差：0.49835635244053716
# Elapsed time: 63.29676342010498 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 268 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 268 个用户的训练
# 当前用户误差：0.4524489117762842
# Elapsed time: 65.08647298812866 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 269 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 269 个用户的训练
# 当前用户误差：0.4987917630651648
# Elapsed time: 64.41910672187805 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 270 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 270 个用户的训练
# 当前用户误差：0.5643114626368031
# Elapsed time: 64.94185209274292 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 271 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 271 个用户的训练
# 当前用户误差：0.5136059619003982
# Elapsed time: 64.82547974586487 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 272 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 272 个用户的训练
# 当前用户误差：0.41973734320748657
# Elapsed time: 63.5964515209198 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 273 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 273 个用户的训练
# 当前用户误差：0.36478716671905587
# Elapsed time: 65.45814633369446 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 274 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 274 个用户的训练
# 当前用户误差：0.3881737105451533
# Elapsed time: 65.22250437736511 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 275 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 275 个用户的训练
# 当前用户误差：0.6703349744482082
# Elapsed time: 65.63385319709778 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# epoch =  4
# finish, 结束第 286 个用户的训练
# 当前用户误差：1.2980157572365305
# Elapsed time: 62.948784828186035 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 287 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 287 个用户的训练
# 当前用户误差：0.49446649394450526
# Elapsed time: 62.434226512908936 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 288 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 288 个用户的训练
# 当前用户误差：0.5211770252970495
# Elapsed time: 62.8245313167572 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 289 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 289 个用户的训练
# 当前用户误差：0.382630443697187
# Elapsed time: 62.82174038887024 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 290 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 290 个用户的训练
# 当前用户误差：0.3776175733776052
# Elapsed time: 63.195239782333374 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 291 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 291 个用户的训练
# 当前用户误差：0.6528288613097327
# Elapsed time: 63.06259870529175 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 292 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 292 个用户的训练
# 当前用户误差：0.611280268896024
# Elapsed time: 62.57535243034363 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 293 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 293 个用户的训练
# 当前用户误差：0.5579863082772226
# Elapsed time: 62.52867770195007 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 294 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 294 个用户的训练
# 当前用户误差：0.47017644243890105
# Elapsed time: 62.602972984313965 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 295 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 295 个用户的训练
# 当前用户误差：0.5497782284947759
# Elapsed time: 62.80132985115051 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 296 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 296 个用户的训练
# 当前用户误差：0.46118749618560007
# Elapsed time: 62.80115795135498 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 297 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 297 个用户的训练
# 当前用户误差：0.3635801113581726
# Elapsed time: 63.18646168708801 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 298 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 298 个用户的训练
# 当前用户误差：0.5177408662797819
# Elapsed time: 63.74778938293457 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 299 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 299 个用户的训练
# 当前用户误差：0.5688342107255974
# Elapsed time: 63.553327560424805 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 300 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 300 个用户的训练
# 当前用户误差：0.5657213229886131
# Elapsed time: 62.227391958236694 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 301 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 301 个用户的训练
# 当前用户误差：0.8428684511222095
# Elapsed time: 62.54223608970642 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 302 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 302 个用户的训练
# 当前用户误差：0.879306443293714
# Elapsed time: 62.73623871803284 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 303 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 303 个用户的训练
# 当前用户误差：1.8736976743878204
# Elapsed time: 62.079540967941284 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 304 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 304 个用户的训练
# 当前用户误差：0.40645481121079546
# Elapsed time: 62.38348722457886 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 305 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 305 个用户的训练
# 当前用户误差：0.40059779635553605
# Elapsed time: 62.32757258415222 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 306 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 306 个用户的训练
# 当前用户误差：0.4911257456979876
# Elapsed time: 62.82378315925598 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 307 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 307 个用户的训练
# 当前用户误差：0.3657208560877478
# Elapsed time: 62.72726249694824 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 308 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 308 个用户的训练
# 当前用户误差：0.48635907366907183
# Elapsed time: 63.62319302558899 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 309 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 309 个用户的训练
# 当前用户误差：0.5991446116274307
# Elapsed time: 64.95061206817627 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 310 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 310 个用户的训练
# 当前用户误差：0.3768946046493152
# Elapsed time: 63.638447284698486 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 311 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 311 个用户的训练
# 当前用户误差：1.17816829116403
# Elapsed time: 63.68137264251709 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 312 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 312 个用户的训练
# 当前用户误差：0.45430077101674937
# Elapsed time: 63.89616370201111 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 313 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 313 个用户的训练
# 当前用户误差：0.42574165232285033
# Elapsed time: 64.07947874069214 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 314 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 314 个用户的训练
# 当前用户误差：0.5047795981200188
# Elapsed time: 64.30781626701355 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 315 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 315 个用户的训练
# 当前用户误差：0.4886850312974477
# Elapsed time: 63.92142105102539 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 316 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 316 个用户的训练
# 当前用户误差：0.5699375011706226
# Elapsed time: 63.79329562187195 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 317 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 317 个用户的训练
# 当前用户误差：0.616091846304165
# Elapsed time: 64.30726456642151 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 318 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 318 个用户的训练
# 当前用户误差：1.2237266827383388
# Elapsed time: 64.03619384765625 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 319 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 319 个用户的训练
# 当前用户误差：1.0966678696382428
# Elapsed time: 64.08454990386963 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 320 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 320 个用户的训练
# 当前用户误差：0.839836044121643
# Elapsed time: 64.3940224647522 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 321 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 321 个用户的训练
# 当前用户误差：0.8700619406825464
# Elapsed time: 64.14124321937561 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 322 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 322 个用户的训练
# 当前用户误差：0.5156567472787928
# Elapsed time: 63.06164216995239 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 323 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 323 个用户的训练
# 当前用户误差：0.42591694308161004
# Elapsed time: 62.480828285217285 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 324 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 324 个用户的训练
# 当前用户误差：0.8923844326446412
# Elapsed time: 62.785112380981445 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 325 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 325 个用户的训练
# 当前用户误差：0.9136483467673375
# Elapsed time: 62.16942262649536 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 326 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 326 个用户的训练
# 当前用户误差：0.5940836149770493
# Elapsed time: 62.01516628265381 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 327 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 327 个用户的训练
# 当前用户误差：0.49889548405514283
# Elapsed time: 62.16472601890564 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 328 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 328 个用户的训练
# 当前用户误差：0.5138471101553502
# Elapsed time: 62.57331728935242 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 329 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 329 个用户的训练
# 当前用户误差：0.2953259360722544
# Elapsed time: 62.66202092170715 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 330 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 330 个用户的训练
# 当前用户误差：0.5545646056926036
# Elapsed time: 62.706804037094116 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 331 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 331 个用户的训练
# 当前用户误差：0.4459322549793211
# Elapsed time: 62.65946340560913 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 332 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 332 个用户的训练
# 当前用户误差：0.454464551689807
# Elapsed time: 62.52384305000305 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 333 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 333 个用户的训练
# 当前用户误差：0.7189632690399144
# Elapsed time: 62.55659461021423 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 334 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 334 个用户的训练
# 当前用户误差：0.732064587696125
# Elapsed time: 63.20593595504761 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 335 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 335 个用户的训练
# 当前用户误差：0.5257319017408123
# Elapsed time: 64.3614330291748 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 336 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 336 个用户的训练
# 当前用户误差：0.4844392634477043
# Elapsed time: 65.39035987854004 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 337 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 337 个用户的训练
# 当前用户误差：0.6714945217550227
# Elapsed time: 65.70509076118469 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 338 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 338 个用户的训练
# 当前用户误差：0.5237409328894103
# Elapsed time: 65.31712031364441 seconds
# 已保存文件user_noisy.txt
# 已加载文件: ./user_noisy.txt
# start, 开始第 339 个用户的训练
# epoch =  1
# epoch =  2
# epoch =  3
# epoch =  4
# finish, 结束第 339 个用户的训练
# 当前用户误差：0.497958180444545
# Elapsed time: 65.992422580719 seconds

# %%
# filepath = './user_noisy.txt'
# print(f"已加载文件: {filepath}")
# dataset2 = MyDataset2(filepath)

# D = Discriminator()

# #for k in range(339):
# #image_data_tensor = dataset2[0] #原始数据，

# start_time = time.time()  # 获取开始时间
# for i in range(300):# !!!!!!!!!!!!!!!!!!!!!!记得改回300
#     image_data_tensor = dataset2[i]
#     #训练判别器 - 真实数据
#     D.train(real_data_tensor, torch.cuda.FloatTensor([1.0], device=device))

#     #训练判别器 - 生成的假数据
#     fake_data = generate_random_image(5825).to(device)
#     D.train(fake_data, torch.cuda.FloatTensor([0.0], device=device))
#     pass

# # create Discriminator and Generator
# # D = Discriminator().to(device)
# G = Generator().to(device)

# epochs = 4
# #print("start, 开始第 {} 个用户的训练".format(k+1))
# print("start, 开始第1个用户的训练")

# for epoch in range(epochs):
#     print("epoch = ", epoch + 1)

#     # train Discriminator and Generator

#     for image_data_tensor in dataset2:
# #         image_data_tensor = torch.from_numpy(image_data_tensor).float()
# #         image_data_tensor = image_data_tensor.to(device)

#         true_labels = torch.tensor([1.0], dtype=torch.float).to(device)
#         D.train(image_data_tensor, true_labels)

#         fake_images = G.forward(generate_random_seed(100)).detach()
#         false_labels = torch.tensor([0.0], dtype=torch.float).to(device)
#         D.train(fake_images, false_labels)

#         # train generator
#         for i in range(5):
#             G.train(D, generate_random_seed(100), torch.tensor([1.0], dtype=torch.float).to(device))
#         pass
# pass
# #print("finish, 结束第 {} 个用户的训练".format(k+1))
# print("finish, 结束第1个用户的训练")

# output = G.forward(generate_random_seed(100))
# output_cpu = output.detach().cpu().numpy()
# unnormalize_output_cpu = dataset2.unnormalize(output_cpu)
# total_output.append(unnormalize_output_cpu)
# #numpy.savetxt('output.txt', output_cpu, delimiter='\t', fmt='%f')


# sum = 0
# # 获取第k个用户真实数据
# #image_values = dataset[k]  # 使用__getitem__方法
# image_values = dataset[0]
# for i in range(5825):
#     # 获取第k个用户第i个服务数据，与生成器结果进行计算误差
#     sum += (output_cpu[i] - image_values[i].item())**2

# sum /= 5825
# sum = math.sqrt(sum)
# rmse += sum
# print("当前用户误差：" + str(sum))
# end_time = time.time()  # 获取结束时间
# elapsed_time = end_time - start_time  # 计算经过的时间
# print(f"Elapsed time: {elapsed_time} seconds")

# %%
total_output = numpy.array(total_output) 
total_output.reshape(-1, 5825)
numpy.savetxt('output.txt', total_output, delimiter='\t', fmt='%f')
print(rmse / 339)
# Out:
# 0.5716889154195436
